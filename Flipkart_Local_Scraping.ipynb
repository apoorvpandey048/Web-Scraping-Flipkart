# %%
import os
import pandas as pd
from bs4 import BeautifulSoup



# Initialize lists to store all extracted data across multiple files
product_names = []
prices = []
max_powers = []
displacements = []
brake_fronts = []
tire_types = []
ratings = []
num_ratings_list = []
num_reviews_list = []

# Function to parse each HTML page and extract the data
def parse_html_page(html_file):
    with open(html_file, "r", encoding="utf-8") as file:
        html_content = file.read()

    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(html_content, 'html.parser')

    # Assuming product_cards is a list of card divs or similar elements
    product_cards = soup.find_all("div", class_="_75nlfW")  # Replace with correct class or tag

    # Lists to store data for the current page
    page_product_names = []
    page_prices = []
    page_max_powers = []
    page_displacements = []
    page_brake_fronts = []
    page_tire_types = []
    page_ratings = []
    page_num_ratings_list = []
    page_num_reviews_list = []

    # Extract data from each product card
    for product_card in product_cards:
        # Extract Product Name
        product_name_div = product_card.find("div", class_="KzDlHZ")
        product_name = product_name_div.text.strip() if product_name_div else "N/A"

        # Extract Price
        price_div = product_card.find("div", class_="Nx9bqj _4b5DiR")
        price = price_div.text.strip() if price_div else "N/A"

        # Extract Maximum Power, Displacement, Brake Front, Tire Type, Console Features, and Warranty Statement
        details_div = product_card.find("div", class_="_6NESgJ")
        details = details_div.find_all("li", class_="J+igdf") if details_div else []

        max_power = details[0].text.strip() if len(details) > 0 else "N/A"
        displacement = details[1].text.strip() if len(details) > 1 else "N/A"
        brake_front = details[2].text.strip() if len(details) > 2 else "N/A"
        tire_type = details[3].text.strip() if len(details) > 3 else "N/A"

        # Extract Ratings, Number of Ratings, and Reviews
        ratings_div = product_card.find("div", class_="_5OesEi")
        rating = "N/A"
        num_ratings = "N/A"
        num_reviews = "N/A"

        if ratings_div:
            rating_span = ratings_div.find("div", class_="XQDdHH")
            rating = rating_span.text.strip() if rating_span else "N/A"
            
            review_span = ratings_div.find("span", class_="Wphh3N")
            ratings_reviews = review_span.text.strip() if review_span else "N/A"
            
            if "Ratings" in ratings_reviews and "Reviews" in ratings_reviews:
                num_ratings = ratings_reviews.split("Ratings")[0].strip()
                num_reviews = ratings_reviews.split("Reviews")[0].split("&")[-1].strip()

        # Append the extracted data to the lists for the current page
        page_product_names.append(product_name)
        page_prices.append(price)
        page_max_powers.append(max_power)
        page_displacements.append(displacement)
        page_brake_fronts.append(brake_front)
        page_tire_types.append(tire_type)
        page_ratings.append(rating)
        page_num_ratings_list.append(num_ratings)
        page_num_reviews_list.append(num_reviews)

    # Return the lists for the current page
    return {
        "Product Name": page_product_names,
        "Price": page_prices,
        "Maximum Power": page_max_powers,
        "Displacement": page_displacements,
        "Brake Front": page_brake_fronts,
        "Tire Type": page_tire_types,
        "Rating": page_ratings,
        "Number of Ratings": page_num_ratings_list,
        "Number of Reviews": page_num_reviews_list,
    }

# Iterate through all HTML files in the directory and parse them
all_data = []
for i in range(1, 3):  # Change this range based on the number of pages you want to scrape
    html_file = f"flipkart_page_{i}.html"
    if os.path.exists(html_file):
        page_data = parse_html_page(html_file)
        all_data.append(page_data)

# Combine all the data from each page into a single DataFrame
df = pd.DataFrame()

for page_data in all_data:
    temp_df = pd.DataFrame(page_data)
    df = pd.concat([df, temp_df], ignore_index=True)

# Save the combined DataFrame to a CSV file
df.to_csv("flipkart_product_data_all_pages.csv", index=False)

# Print the DataFrame
print(df)
# Out:
#                                          Product Name      Price  \
# 0   Hero Splendor+ (Non i3S) Booking for Ex-Showro...    ₹76,526
# 1   BAJAJ PULSAR 220 F (UG) Booking for Ex-Showroo...  ₹1,40,954
# 2   Hero Super Splendor (Disc) Booking for Ex-Show...    ₹84,198
# 3   Hero Glamour XTEC (Drum) Booking for Ex-Showro...    ₹90,794
# 4   BAJAJ Pulsar 125 (CARBON FIBRE SINGLE SEAT UG)...    ₹89,350
# 5   Hero Super Splendor Xtec (Drum) Booking for Ex...    ₹83,150
# 6   Hero XTREME 125R (ABS) Booking for Ex-Showroom...  ₹1,03,035
# 7   BAJAJ Pulsar 150 (Single Disc UG) Booking for ...  ₹1,14,438
# 8   BAJAJ Avenger (220 CRUISE) Booking for Ex-Show...  ₹1,47,507
# 9   Hero Glamour XTEC (Disc) Booking for Ex-Showro...    ₹94,998
# 10  Hero XTREME 125R (IBS) Booking for Ex-Showroom...    ₹97,107
# 11  Hero Super Splendor (Drum) Booking for Ex-Show...    ₹81,498
# 12  BAJAJ Pulsar N 150 (Twin Disc UG) Booking for ...  ₹1,25,728
# 13  Hero Xpulse 200 4V (ABS Disc) Booking for Ex-S...  ₹1,48,141
# 14  Hero HF Deluxe (Non i3S with Kick Start) Booki...    ₹61,689
# 15  BAJAJ Pulsar 150 (Twin Disc UG) Booking for Ex...  ₹1,18,476
# 16  BAJAJ Pulsar 125 (CARBON FIBRE SPLIT SEAT UG) ...    ₹91,181
# 17  BAJAJ Platina 100 (ES Drum) Booking for Ex-Sho...    ₹68,384
# 18  BAJAJ Pulsar 125 (NEON DISC SINGLE SEAT) Booki...    ₹82,944
# 19  Hero Glamour (Drum) Booking for Ex-Showroom Price    ₹83,948
# 20  Hero Splendor+ (i3S) Booking for Ex-Showroom P...    ₹77,636
# 21  BAJAJ PULSAR N 160 (UG) Booking for Ex-Showroo...  ₹1,41,990
# 22     Hero Mavrick 440 Booking for Ex-Showroom Price  ₹2,24,000
# 23  BAJAJ Dominar (250) Booking for Ex-Showroom Price  ₹1,86,669
# 24  BAJAJ Pulsar 150 (Twin Disc UG) Booking for Ex...  ₹1,18,476
# 25  BAJAJ Pulsar 125 (CARBON FIBRE SPLIT SEAT UG) ...    ₹91,181
# 26  BAJAJ Platina 100 (ES Drum) Booking for Ex-Sho...    ₹68,384
# 27  Hero Splendor+ (Non i3S) Booking for Ex-Showro...    ₹76,526
# 28  BAJAJ Dominar (400 UG) Booking for Ex-Showroom...  ₹2,32,833
# 29  BAJAJ Pulsar NS 200 (UG) Booking for Ex-Showro...  ₹1,61,594
# 30  BAJAJ Platina 110 (Drum) Booking for Ex-Showro...    ₹73,606
# 31  Hero Xtreme 160R 4V Booking for Ex-Showroom Price  ₹1,38,000
# 32  BAJAJ Avenger (160 STREET) Booking for Ex-Show...  ₹1,20,870
# 33   BAJAJ PULSAR N 250 Booking for Ex-Showroom Price  ₹1,53,197
# 34        BAJAJ CT 110X Booking for Ex-Showroom Price    ₹70,035
# 35  BAJAJ Pulsar NS 125 (UG) Booking for Ex-Showro...  ₹1,08,467
# 36  Hero Glamour (Disc) Booking for Ex-Showroom Price    ₹87,948
# 37  BAJAJ Pulsar NS 160 (UG) Booking for Ex-Showro...  ₹1,47,334
# 38  Hero HF Deluxe (i3S with Self Start) Booking f...    ₹69,864
# 39  Hero HF Deluxe (Non i3S with Self Start) Booki...    ₹68,264
# 40  Hero Super Splendor Xtec (Disc) Booking for Ex...    ₹90,228
# 41        BAJAJ CT 125X Booking for Ex-Showroom Price    ₹78,125
#
#                                    Maximum Power             Displacement  \
# 0               Maximum Power: 5.9 kW @ 8000 rpm    Displacement: 97.2 cc
# 1      Maximum Power: 15 kW (20.4 PS) @ 8500 rpm     Displacement: 220 cc
# 2                            Maximum Power: 10.7   Displacement: 124.7 cc
# 3                            Maximum Power: 10.7   Displacement: 124.7 cc
# 4              Maximum Power: 8.68 kW @ 8500 rpm  Displacement: 124.38 cc
# 5          Maximum Power: 10.7 BHP (at 7500 RPM)     Displacement: 125 cc
# 6               Maximum Power: 8.5 kW @ 8250 rpm   Displacement: 124.7 cc
# 7      Maximum Power: 10.3 kW (14 PS) @ 8500 rpm   Displacement: 149.5 cc
# 8                Maximum Power: 14 kW @ 8400 rpm     Displacement: 220 cc
# 9                            Maximum Power: 10.7   Displacement: 124.7 cc
# 10              Maximum Power: 8.5 kW @ 8250 rpm   Displacement: 124.7 cc
# 11                           Maximum Power: 10.7   Displacement: 124.7 cc
# 12  Maximum Power: 10.66 kW (14.5 PS) @ 8500 rpm  Displacement: 149.68 cc
# 13                           Maximum Power: 19.1   Displacement: 199.6 cc
# 14                           Maximum Power: 7.91   Displacement: 97.22 cc
# 15     Maximum Power: 10.3 kW (14 PS) @ 8500 rpm   Displacement: 149.5 cc
# 16             Maximum Power: 8.68 kW @ 8500 rpm  Displacement: 124.38 cc
# 17             Maximum Power: 7.9 Ps @ 7,500 rpm     Displacement: 102 cc
# 18             Maximum Power: 8.68 kW @ 8500 rpm  Displacement: 124.38 cc
# 19          Maximum Power: 7.75 KW (at 7500 rpm)     Displacement: 125 cc
# 20              Maximum Power: 5.9 kW @ 8000 rpm    Displacement: 97.2 cc
# 21            Maximum Power: 11.77 KW @ 8750 rpm  Displacement: 164.82 cc
# 22     Maximum Power: 20.13 kW/27 bhp @ 6000 rpm     Displacement: 440 cc
# 23            Maximum Power: 19.86 kW @ 8500 rpm  Displacement: 248.77 cc
# 24     Maximum Power: 10.3 kW (14 PS) @ 8500 rpm   Displacement: 149.5 cc
# 25             Maximum Power: 8.68 kW @ 8500 rpm  Displacement: 124.38 cc
# 15  BAJAJ Pulsar 150 (Twin Disc UG) Booking for Ex...  ₹1,18,476
# 16  BAJAJ Pulsar 125 (CARBON FIBRE SPLIT SEAT UG) ...    ₹91,181
# 17  BAJAJ Platina 100 (ES Drum) Booking for Ex-Sho...    ₹68,384
# 18  BAJAJ Pulsar 125 (NEON DISC SINGLE SEAT) Booki...    ₹82,944
# 19  Hero Glamour (Drum) Booking for Ex-Showroom Price    ₹83,948
# 20  Hero Splendor+ (i3S) Booking for Ex-Showroom P...    ₹77,636
# 21  BAJAJ PULSAR N 160 (UG) Booking for Ex-Showroo...  ₹1,41,990
# 22     Hero Mavrick 440 Booking for Ex-Showroom Price  ₹2,24,000
# 23  BAJAJ Dominar (250) Booking for Ex-Showroom Price  ₹1,86,669
# 24  BAJAJ Pulsar 150 (Twin Disc UG) Booking for Ex...  ₹1,18,476
# 25  BAJAJ Pulsar 125 (CARBON FIBRE SPLIT SEAT UG) ...    ₹91,181
# 26  BAJAJ Platina 100 (ES Drum) Booking for Ex-Sho...    ₹68,384
# 27  Hero Splendor+ (Non i3S) Booking for Ex-Showro...    ₹76,526
# 28  BAJAJ Dominar (400 UG) Booking for Ex-Showroom...  ₹2,32,833
# 29  BAJAJ Pulsar NS 200 (UG) Booking for Ex-Showro...  ₹1,61,594
# 30  BAJAJ Platina 110 (Drum) Booking for Ex-Showro...    ₹73,606
# 31  Hero Xtreme 160R 4V Booking for Ex-Showroom Price  ₹1,38,000
# 32  BAJAJ Avenger (160 STREET) Booking for Ex-Show...  ₹1,20,870
# 33   BAJAJ PULSAR N 250 Booking for Ex-Showroom Price  ₹1,53,197
# 34        BAJAJ CT 110X Booking for Ex-Showroom Price    ₹70,035
# 35  BAJAJ Pulsar NS 125 (UG) Booking for Ex-Showro...  ₹1,08,467
# 36  Hero Glamour (Disc) Booking for Ex-Showroom Price    ₹87,948
# 37  BAJAJ Pulsar NS 160 (UG) Booking for Ex-Showro...  ₹1,47,334
# 38  Hero HF Deluxe (i3S with Self Start) Booking f...    ₹69,864
# 39  Hero HF Deluxe (Non i3S with Self Start) Booki...    ₹68,264
# 40  Hero Super Splendor Xtec (Disc) Booking for Ex...    ₹90,228
# 41        BAJAJ CT 125X Booking for Ex-Showroom Price    ₹78,125
#
#                                    Maximum Power             Displacement  \
# 0               Maximum Power: 5.9 kW @ 8000 rpm    Displacement: 97.2 cc
# 1      Maximum Power: 15 kW (20.4 PS) @ 8500 rpm     Displacement: 220 cc
# 2                            Maximum Power: 10.7   Displacement: 124.7 cc
# 3                            Maximum Power: 10.7   Displacement: 124.7 cc
# 4              Maximum Power: 8.68 kW @ 8500 rpm  Displacement: 124.38 cc
# 5          Maximum Power: 10.7 BHP (at 7500 RPM)     Displacement: 125 cc
# 6               Maximum Power: 8.5 kW @ 8250 rpm   Displacement: 124.7 cc
# 7      Maximum Power: 10.3 kW (14 PS) @ 8500 rpm   Displacement: 149.5 cc
# 8                Maximum Power: 14 kW @ 8400 rpm     Displacement: 220 cc
# 9                            Maximum Power: 10.7   Displacement: 124.7 cc
# 10              Maximum Power: 8.5 kW @ 8250 rpm   Displacement: 124.7 cc
# 11                           Maximum Power: 10.7   Displacement: 124.7 cc
# 12  Maximum Power: 10.66 kW (14.5 PS) @ 8500 rpm  Displacement: 149.68 cc
# 13                           Maximum Power: 19.1   Displacement: 199.6 cc
# 14                           Maximum Power: 7.91   Displacement: 97.22 cc
# 15     Maximum Power: 10.3 kW (14 PS) @ 8500 rpm   Displacement: 149.5 cc
# 16             Maximum Power: 8.68 kW @ 8500 rpm  Displacement: 124.38 cc
# 17             Maximum Power: 7.9 Ps @ 7,500 rpm     Displacement: 102 cc
# 18             Maximum Power: 8.68 kW @ 8500 rpm  Displacement: 124.38 cc
# 19          Maximum Power: 7.75 KW (at 7500 rpm)     Displacement: 125 cc
# 20              Maximum Power: 5.9 kW @ 8000 rpm    Displacement: 97.2 cc
# 21            Maximum Power: 11.77 KW @ 8750 rpm  Displacement: 164.82 cc
# 22     Maximum Power: 20.13 kW/27 bhp @ 6000 rpm     Displacement: 440 cc
# 23            Maximum Power: 19.86 kW @ 8500 rpm  Displacement: 248.77 cc
# 24     Maximum Power: 10.3 kW (14 PS) @ 8500 rpm   Displacement: 149.5 cc
# 25             Maximum Power: 8.68 kW @ 8500 rpm  Displacement: 124.38 cc
# 26             Maximum Power: 7.9 Ps @ 7,500 rpm     Displacement: 102 cc
# 27              Maximum Power: 5.9 kW @ 8000 rpm    Displacement: 97.2 cc
# 28             Maximum Power: 29.4 KW @ 8800 rpm   Displacement: 373.3 cc
# 29     Maximum Power: 18 kW (24.5 PS) @ 9750 rpm   Displacement: 199.5 cc
# 30              Maximum Power: 8.6 Ps @ 7,000rpm  Displacement: 115.45 cc
# 31          Maximum Power: 16.9 PS (at 8500 RPM)   Displacement: 163.2 cc
# 32               Maximum Power: 11 KW @ 8500 rpm     Displacement: 160 cc
# 33     Maximum Power: 15 kW (20.4 PS) @ 8500 rpm  Displacement: 249.07 cc
# 34              Maximum Power: 8.6 Ps @ 7,000rpm  Displacement: 115.45 cc
# 35             Maximum Power: 8.82 kW @ 8500 rpm  Displacement: 124.45 cc
# 36          Maximum Power: 7.75 KW (at 7500 rpm)     Displacement: 125 cc
# 37   Maximum Power: 12.7 kW (17.2 PS) @ 9000 rpm   Displacement: 160.3 cc
# 38                           Maximum Power: 7.91   Displacement: 97.22 cc
# 39                           Maximum Power: 7.91   Displacement: 97.22 cc
# 40         Maximum Power: 10.7 BHP (at 7500 RPM)     Displacement: 125 cc
# 41               Maximum Power: 10.9 Ps @8000rpm  Displacement: 124.45 cc
#
#           Brake Front            Tire Type Rating Number of Ratings  \
# 0   Brake Front: Drum  Tire Type: Tubeless    4.5             5,695
# 1   Brake Front: Disc  Tire Type: Tubeless    4.3                21
# 2   Brake Front: Disc  Tire Type: Tubeless    4.5               513
# 3   Brake Front: Drum  Tire Type: Tubeless    4.5             1,860
# 4   Brake Front: Disc  Tire Type: Tubeless    4.5               456
